# %% [markdown]
# # Hospital Analysis Index
# The detailed analysis has been separated into dedicated notebooks for cleaner organization and to avoid duplicated plots and statistics.
#
# - `hospital_demographics.ipynb` — demographic and outcome distributions
# - `hospital_financial_analysis.ipynb` — cost, stay, and readmission insights
# - `hospital_geographic_analysis.ipynb` — time-series and geographic breakdowns
